# %%
# %run __main__.py
# Out:
# 2020-08-03 23:58:25 +1200, INFO, ccc4prc, Program started.
# 2020-08-03 23:58:34 +1200, INFO, MachineLearning,               precision    recall  f1-score   support
#
#           No  0.85810811 0.89436620 0.87586207       142
#          Yes  0.48275862 0.40000000 0.43750000        35
#
#     accuracy                      0.79661017       177
#    macro avg  0.67043336 0.64718310 0.65668103       177
# weighted avg  0.78388646 0.79661017 0.78918030       177
#
# 2020-08-03 23:58:34 +1200, INFO, MachineLearning, ......Active Learning Starts......
# 2020-08-03 23:58:34 +1200, INFO, MachineLearning, Scenario: Pool-based sampling...
# 2020-08-03 23:58:34 +1200, INFO, MachineLearning, Query Strategy: Least Confidence...
# 2020-08-03 23:59:12 +1200, INFO, MachineLearning, Instance No. 1, label (No): 50.00%, label (Yes): 50.00%, comment_id: 133012964
# body: Thanks Wendy.
#
# ...
