# %%
from classifier import DialogueActClassifierFactory
from joblib import load
from pandas import DataFrame, option_context, read_csv
from pathlib import Path

pcc_clf = load('./models/program_comprehension_challenge_classifier.pickle') 
dac_factory = DialogueActClassifierFactory()
dac_clf = dac_factory.get_classifier(classifier_file=Path('./models/dialogue_act_classifier.pickle'), test_set_percentage=10)

training_dataset = read_csv('../master-of-engineering/Assets/BigQuery/training_dataset.csv')
test_dataset = read_csv('../master-of-engineering/Assets/BigQuery/test_dataset.csv')

FEATURES = ['body', 'dialogue_act_classification_ml', 'comment_is_by_author']
LABEL = 'program_comprehension_challenge'

X_train = training_dataset[FEATURES]
X_test = test_dataset[FEATURES]
y_train = training_dataset[LABEL]
y_true = test_dataset[LABEL]

# %%
from sklearn import metrics

y_pred = pcc_clf.predict(X_test)

report = metrics.classification_report(y_true, y_pred, digits=8)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#           No  0.88695652 0.91891892 0.90265487       111
#          Yes  0.74285714 0.66666667 0.70270270        39
#
#     accuracy                      0.85333333       150
#    macro avg  0.81490683 0.79279279 0.80267878       150
# weighted avg  0.84949068 0.85333333 0.85066730       150

# %%
# content_analysis_dataset = read_csv('../master-of-engineering/Assets/BigQuery/content_analysis_dataset.csv')
# content_analysis_dataset['program_comprehension_challenge_new'] = ''

# for idx, row in content_analysis_dataset.iterrows():
#     body = row['body']
#     comment_is_by_author = row['comment_is_by_author']
#     dialogue_act_classification = row['dialogue_act_classification_ml']
#     prediction = pcc_clf.predict(
#         DataFrame(
#             {
#                 'body': [body], 
#                 'comment_is_by_author': [comment_is_by_author], 
#                 'dialogue_act_classification_ml': [dialogue_act_classification]
#             }))

#     row['program_comprehension_challenge_new'] = prediction[0]
#     content_analysis_dataset.loc[idx] = row

# content_analysis_dataset.to_csv('/Volumes/RamDisk/content_analysis_dataset_new.csv', index=False, header=True, mode='w')

# %%
experiment_dataset = read_csv('/Volumes/RamDisk/results_20190503_1403_cleaned.csv')

# %%
from pandas import concat

content_analysis_dataset = concat([
    training_dataset.loc[training_dataset['program_comprehension_challenge']=='Yes'], 
    test_dataset.loc[test_dataset['program_comprehension_challenge']=='Yes']
    ])

sample_size = 384 - content_analysis_dataset.shape[0] # 95% Confidence Level + 5% Confidence Interval with a population of 1036743 -> Sample Size = 384, already analyzed in training dataset and test dataset.
sample_size
# Out:
# 253

# %%
experiment_dataset_total_rows = experiment_dataset.shape[0]
print(experiment_dataset_total_rows)
indices_already_sampled = list(experiment_dataset.loc[experiment_dataset['comment_id'].isin(content_analysis_dataset['comment_id'])].index)
print(indices_already_sampled)
# Out:
# 1036743
# [509, 726, 17798, 24155, 32099, 36464, 43032, 54431, 56313, 69258, 73270, 80162, 90511, 105051, 110503, 129628, 132855, 133232, 133516, 163355, 167086, 185939, 189728, 197447, 209669, 214812, 232697, 235018, 246296, 252758, 258339, 259928, 270277, 274453, 284698, 297264, 315545, 330692, 333599, 338031, 340343, 346345, 354605, 364763, 368760, 373140, 380565, 380639, 389432, 403936, 405359, 413884, 424418, 432183, 436822, 456947, 461248, 474321, 506840, 513293, 522487, 526100, 527975, 534546, 536108, 542999, 547634, 565844, 566844, 579035, 595607, 596015, 600716, 609584, 611753, 615305, 619572, 622248, 626921, 632953, 644196, 664099, 668030, 668995, 690642, 701256, 705033, 707035, 715644, 726526, 733106, 752516, 761659, 762103, 762279, 765988, 775082, 776089, 805526, 810905, 813272, 814306, 818502, 818629, 824256, 827388, 836138, 841892, 843924, 857463, 866385, 868061, 886945, 887040, 907182, 916756, 919472, 935851, 947274, 947500, 951413, 956529, 976020, 987354, 990899, 991399, 999428, 1003989, 1005538, 1032415, 1035319]

# %%
from random import choice

experiment_dataset_range = range(0, experiment_dataset_total_rows)
counter_yes = 0
counter_total = 0
while counter_yes < sample_size:
    counter_total += 1
    random_index = choice([i for i in experiment_dataset_range if i not in indices_already_sampled])
    indices_already_sampled.append(random_index)
    row = experiment_dataset.loc[random_index]
    body = row['body']
    comment_is_by_author = row['comment_is_by_author']
    dialogue_act_classification = dac_factory.classify(body)
    prediction = pcc_clf.predict(
        DataFrame(
            {
                'body': [body], 
                'comment_is_by_author': [comment_is_by_author], 
                'dialogue_act_classification_ml': [dialogue_act_classification]
            }))

    if prediction[0] == 'Yes':
        row['dialogue_act_classification_ml'] = dialogue_act_classification
        row['topic_keywords'] = ''
        row['program_comprehension_challenge'] = prediction[0]
        row['problem_encountered'] = ''
        content_analysis_dataset = content_analysis_dataset.append(row)
        counter_yes += 1  

    print(f'Counter (Total): {counter_total}, Counter (Yes): {counter_yes}, Size of already sampled: {len(indices_already_sampled)}, Random Index: {random_index}')

content_analysis_dataset.to_csv('../master-of-engineering/Assets/BigQuery/content_analysis_dataset.csv', index=False, header=True, mode='w')
# Out:
# r (Yes): 211, Size of already sampled: 1296, Random Index: 806099
# Counter (Total): 1166, Counter (Yes): 211, Size of already sampled: 1297, Random Index: 389064
# Counter (Total): 1167, Counter (Yes): 211, Size of already sampled: 1298, Random Index: 102192
# Counter (Total): 1168, Counter (Yes): 211, Size of already sampled: 1299, Random Index: 346876
# Counter (Total): 1169, Counter (Yes): 211, Size of already sampled: 1300, Random Index: 626523
# Counter (Total): 1170, Counter (Yes): 211, Size of already sampled: 1301, Random Index: 197768
# Counter (Total): 1171, Counter (Yes): 211, Size of already sampled: 1302, Random Index: 53484
# Counter (Total): 1172, Counter (Yes): 212, Size of already sampled: 1303, Random Index: 259236
# Counter (Total): 1173, Counter (Yes): 212, Size of already sampled: 1304, Random Index: 766109
# Counter (Total): 1174, Counter (Yes): 212, Size of already sampled: 1305, Random Index: 822989
# Counter (Total): 1175, Counter (Yes): 212, Size of already sampled: 1306, Random Index: 490402
# Counter (Total): 1176, Counter (Yes): 212, Size of already sampled: 1307, Random Index: 383290
# Counter (Total): 1177, Counter (Yes): 212, Size of already sampled: 1308, Random Index: 439912
# Counter (Total): 1178, Counter (Yes): 212, Size of already sampled: 1309, Random Index: 1117
# Counter (Total): 1179, Counter (Yes): 212, Size of already sampled: 1310, Random Index: 448228
# Counter (Total): 1180, Counter (Yes): 212, Size of already sampled: 1311, Random Index: 277826
# Counter (Total): 1181, Counter (Yes): 212, Size of already sampled: 1312, Random Index: 793101
# Counter (Total): 1182, Counter (Yes): 213, Size of already sampled: 1313, Random Index: 218597
# Counter (Total): 1183, Counter (Yes): 213, Size of already sampled: 1314, Random Index: 29452
# Counter (Total): 1184, Counter (Yes): 213, Size of already sampled: 1315, Random Index: 218680
# Counter (Total): 1185, Counter (Yes): 213, Size of already sampled: 1316, Random Index: 313462
# Counter (Total): 1186, Counter (Yes): 213, Size of already sampled: 1317, Random Index: 385533
# Counter (Total): 1187, Counter (Yes): 213, Size of already sampled: 1318, Random Index: 373718
# Counter (Total): 1188, Counter (Yes): 213, Size of already sampled: 1319, Random Index: 619041
# Counter (Total): 1189, Counter (Yes): 213, Size of already sampled: 1320, Random Index: 537304
# Counter (Total): 1190, Counter (Yes): 214, Size of already sampled: 1321, Random Index: 805618
# Counter (Total): 1191, Counter (Yes): 214, Size of already sampled: 1322, Random Index: 527521
# Counter (Total): 1192, Counter (Yes): 214, Size of already sampled: 1323, Random Index: 416532
# Counter (Total): 1193, Counter (Yes): 214, Size of already sampled: 1324, Random Index: 177285
# Counter (Total): 1194, Counter (Yes): 214, Size of already sampled: 1325, Random Index: 108854
# Counter (Total): 1195, Counter (Yes): 214, Size of already sampled: 1326, Random Index: 161752
# Counter (Total): 1196, Counter (Yes): 214, Size of already sampled: 1327, Random Index: 151490
# Counter (Total): 1197, Counter (Yes): 215, Size of already sampled: 1328, Random Index: 438541
# Counter (Total): 1198, Counter (Yes): 216, Size of already sampled: 1329, Random Index: 349093
# Counter (Total): 1199, Counter (Yes): 216, Size of already sampled: 1330, Random Index: 598808
# Counter (Total): 1200, Counter (Yes): 216, Size of already sampled: 1331, Random Index: 473462
# Counter (Total): 1201, Counter (Yes): 216, Size of already sampled: 1332, Random Index: 629263
# Counter (Total): 1202, Counter (Yes): 216, Size of already sampled: 1333, Random Index: 920139
# Counter (Total): 1203, Counter (Yes): 216, Size of already sampled: 1334, Random Index: 40864
# Counter (Total): 1204, Counter (Yes): 216, Size of already sampled: 1335, Random Index: 651113
# Counter (Total): 1205, Counter (Yes): 216, Size of already sampled: 1336, Random Index: 484329
# Counter (Total): 1206, Counter (Yes): 216, Size of already sampled: 1337, Random Index: 511128
# Counter (Total): 1207, Counter (Yes): 216, Size of already sampled: 1338, Random Index: 674275
# Counter (Total): 1208, Counter (Yes): 216, Size of already sampled: 1339, Random Index: 796065
# Counter (Total): 1209, Counter (Yes): 216, Size of already sampled: 1340, Random Index: 780811
# Counter (Total): 1210, Counter (Yes): 216, Size of already sampled: 1341, Random Index: 831757
# Counter (Total): 1211, Counter (Yes): 216, Size of already sampled: 1342, Random Index: 930557
# Counter (Total): 1212, Counter (Yes): 216, Size of already sampled: 1343, Random Index: 146676
# Counter (Total): 1213, Counter (Yes): 216, Size of already sampled: 1344, Random Index: 733146
# Counter (Total): 1214, Counter (Yes): 217, Size of already sampled: 1345, Random Index: 883214
# Counter (Total): 1215, Counter (Yes): 217, Size of already sampled: 1346, Random Index: 895354
# Counter (Total): 1216, Counter (Yes): 217, Size of already sampled: 1347, Random Index: 11312
# Counter (Total): 1217, Counter (Yes): 217, Size of already sampled: 1348, Random Index: 45811
# Counter (Total): 1218, Counter (Yes): 218, Size of already sampled: 1349, Random Index: 470714
# Counter (Total): 1219, Counter (Yes): 218, Size of already sampled: 1350, Random Index: 26535
# Counter (Total): 1220, Counter (Yes): 219, Size of already sampled: 1351, Random Index: 655220
# Counter (Total): 1221, Counter (Yes): 219, Size of already sampled: 1352, Random Index: 829923
# Counter (Total): 1222, Counter (Yes): 219, Size of already sampled: 1353, Random Index: 414731
# Counter (Total): 1223, Counter (Yes): 219, Size of already sampled: 1354, Random Index: 104810
# Counter (Total): 1224, Counter (Yes): 219, Size of already sampled: 1355, Random Index: 706374
# Counter (Total): 1225, Counter (Yes): 219, Size of already sampled: 1356, Random Index: 149105
# Counter (Total): 1226, Counter (Yes): 219, Size of already sampled: 1357, Random Index: 90845
# Counter (Total): 1227, Counter (Yes): 219, Size of already sampled: 1358, Random Index: 631137
# Counter (Total): 1228, Counter (Yes): 219, Size of already sampled: 1359, Random Index: 411483
# Counter (Total): 1229, Counter (Yes): 220, Size of already sampled: 1360, Random Index: 835034
# Counter (Total): 1230, Counter (Yes): 220, Size of already sampled: 1361, Random Index: 896784
# Counter (Total): 1231, Counter (Yes): 220, Size of already sampled: 1362, Random Index: 714534
# Counter (Total): 1232, Counter (Yes): 220, Size of already sampled: 1363, Random Index: 367454
# Counter (Total): 1233, Counter (Yes): 220, Size of already sampled: 1364, Random Index: 893099
# Counter (Total): 1234, Counter (Yes): 220, Size of already sampled: 1365, Random Index: 632168
# Counter (Total): 1235, Counter (Yes): 220, Size of already sampled: 1366, Random Index: 311633
# Counter (Total): 1236, Counter (Yes): 221, Size of already sampled: 1367, Random Index: 383745
# Counter (Total): 1237, Counter (Yes): 221, Size of already sampled: 1368, Random Index: 253625
# Counter (Total): 1238, Counter (Yes): 221, Size of already sampled: 1369, Random Index: 478031
# Counter (Total): 1239, Counter (Yes): 221, Size of already sampled: 1370, Random Index: 291200
# Counter (Total): 1240, Counter (Yes): 221, Size of already sampled: 1371, Random Index: 472457
# Counter (Total): 1241, Counter (Yes): 221, Size of already sampled: 1372, Random Index: 721818
# Counter (Total): 1242, Counter (Yes): 221, Size of already sampled: 1373, Random Index: 813042
# Counter (Total): 1243, Counter (Yes): 221, Size of already sampled: 1374, Random Index: 238990
# Counter (Total): 1244, Counter (Yes): 221, Size of already sampled: 1375, Random Index: 401413
# Counter (Total): 1245, Counter (Yes): 221, Size of already sampled: 1376, Random Index: 208583
# Counter (Total): 1246, Counter (Yes): 221, Size of already sampled: 1377, Random Index: 660485
# Counter (Total): 1247, Counter (Yes): 221, Size of already sampled: 1378, Random Index: 741499
# Counter (Total): 1248, Counter (Yes): 221, Size of already sampled: 1379, Random Index: 944508
# Counter (Total): 1249, Counter (Yes): 221, Size of already sampled: 1380, Random Index: 924308
# Counter (Total): 1250, Counter (Yes): 221, Size of already sampled: 1381, Random Index: 929957
# Counter (Total): 1251, Counter (Yes): 221, Size of already sampled: 1382, Random Index: 909227
# Counter (Total): 1252, Counter (Yes): 221, Size of already sampled: 1383, Random Index: 573744
# Counter (Total): 1253, Counter (Yes): 221, Size of already sampled: 1384, Random Index: 573734
# Counter (Total): 1254, Counter (Yes): 222, Size of already sampled: 1385, Random Index: 63502
# Counter (Total): 1255, Counter (Yes): 222, Size of already sampled: 1386, Random Index: 104872
# Counter (Total): 1256, Counter (Yes): 222, Size of already sampled: 1387, Random Index: 802247
# Counter (Total): 1257, Counter (Yes): 223, Size of already sampled: 1388, Random Index: 417210
# Counter (Total): 1258, Counter (Yes): 223, Size of already sampled: 1389, Random Index: 615842
# Counter (Total): 1259, Counter (Yes): 223, Size of already sampled: 1390, Random Index: 138524
# Counter (Total): 1260, Counter (Yes): 223, Size of already sampled: 1391, Random Index: 327135
# Counter (Total): 1261, Counter (Yes): 224, Size of already sampled: 1392, Random Index: 832959
# Counter (Total): 1262, Counter (Yes): 224, Size of already sampled: 1393, Random Index: 242198
# Counter (Total): 1263, Counter (Yes): 224, Size of already sampled: 1394, Random Index: 312498
# Counter (Total): 1264, Counter (Yes): 225, Size of already sampled: 1395, Random Index: 198210
# Counter (Total): 1265, Counter (Yes): 225, Size of already sampled: 1396, Random Index: 663509
# Counter (Total): 1266, Counter (Yes): 226, Size of already sampled: 1397, Random Index: 445553
# Counter (Total): 1267, Counter (Yes): 227, Size of already sampled: 1398, Random Index: 478083
# Counter (Total): 1268, Counter (Yes): 227, Size of already sampled: 1399, Random Index: 639797
# Counter (Total): 1269, Counter (Yes): 228, Size of already sampled: 1400, Random Index: 324654
# Counter (Total): 1270, Counter (Yes): 228, Size of already sampled: 1401, Random Index: 1036532
# Counter (Total): 1271, Counter (Yes): 229, Size of already sampled: 1402, Random Index: 340239
# Counter (Total): 1272, Counter (Yes): 230, Size of already sampled: 1403, Random Index: 893899
# Counter (Total): 1273, Counter (Yes): 230, Size of already sampled: 1404, Random Index: 869992
# Counter (Total): 1274, Counter (Yes): 230, Size of already sampled: 1405, Random Index: 391268
# Counter (Total): 1275, Counter (Yes): 230, Size of already sampled: 1406, Random Index: 344289
# Counter (Total): 1276, Counter (Yes): 230, Size of already sampled: 1407, Random Index: 407814
# Counter (Total): 1277, Counter (Yes): 230, Size of already sampled: 1408, Random Index: 943897
# Counter (Total): 1278, Counter (Yes): 231, Size of already sampled: 1409, Random Index: 722736
# Counter (Total): 1279, Counter (Yes): 231, Size of already sampled: 1410, Random Index: 297098
# Counter (Total): 1280, Counter (Yes): 232, Size of already sampled: 1411, Random Index: 227514
# Counter (Total): 1281, Counter (Yes): 233, Size of already sampled: 1412, Random Index: 923079
# Counter (Total): 1282, Counter (Yes): 233, Size of already sampled: 1413, Random Index: 609044
# Counter (Total): 1283, Counter (Yes): 233, Size of already sampled: 1414, Random Index: 610799
# Counter (Total): 1284, Counter (Yes): 233, Size of already sampled: 1415, Random Index: 744693
# Counter (Total): 1285, Counter (Yes): 233, Size of already sampled: 1416, Random Index: 780891
# Counter (Total): 1286, Counter (Yes): 233, Size of already sampled: 1417, Random Index: 899959
# Counter (Total): 1287, Counter (Yes): 234, Size of already sampled: 1418, Random Index: 708673
# Counter (Total): 1288, Counter (Yes): 234, Size of already sampled: 1419, Random Index: 708352
# Counter (Total): 1289, Counter (Yes): 234, Size of already sampled: 1420, Random Index: 409280
# Counter (Total): 1290, Counter (Yes): 234, Size of already sampled: 1421, Random Index: 509774
# Counter (Total): 1291, Counter (Yes): 234, Size of already sampled: 1422, Random Index: 839405
# Counter (Total): 1292, Counter (Yes): 235, Size of already sampled: 1423, Random Index: 715554
# Counter (Total): 1293, Counter (Yes): 235, Size of already sampled: 1424, Random Index: 651304
# Counter (Total): 1294, Counter (Yes): 235, Size of already sampled: 1425, Random Index: 174454
# Counter (Total): 1295, Counter (Yes): 235, Size of already sampled: 1426, Random Index: 676329
# Counter (Total): 1296, Counter (Yes): 235, Size of already sampled: 1427, Random Index: 805130
# Counter (Total): 1297, Counter (Yes): 235, Size of already sampled: 1428, Random Index: 914110
# Counter (Total): 1298, Counter (Yes): 235, Size of already sampled: 1429, Random Index: 666977
# Counter (Total): 1299, Counter (Yes): 235, Size of already sampled: 1430, Random Index: 829668
# Counter (Total): 1300, Counter (Yes): 235, Size of already sampled: 1431, Random Index: 367009
# Counter (Total): 1301, Counter (Yes): 235, Size of already sampled: 1432, Random Index: 45173
# Counter (Total): 1302, Counter (Yes): 236, Size of already sampled: 1433, Random Index: 173525
# Counter (Total): 1303, Counter (Yes): 236, Size of already sampled: 1434, Random Index: 661022
# Counter (Total): 1304, Counter (Yes): 236, Size of already sampled: 1435, Random Index: 214814
# Counter (Total): 1305, Counter (Yes): 236, Size of already sampled: 1436, Random Index: 511995
# Counter (Total): 1306, Counter (Yes): 236, Size of already sampled: 1437, Random Index: 47879
# Counter (Total): 1307, Counter (Yes): 237, Size of already sampled: 1438, Random Index: 812064
# Counter (Total): 1308, Counter (Yes): 237, Size of already sampled: 1439, Random Index: 517852
# Counter (Total): 1309, Counter (Yes): 238, Size of already sampled: 1440, Random Index: 528345
# Counter (Total): 1310, Counter (Yes): 238, Size of already sampled: 1441, Random Index: 719
# Counter (Total): 1311, Counter (Yes): 239, Size of already sampled: 1442, Random Index: 116450
# Counter (Total): 1312, Counter (Yes): 240, Size of already sampled: 1443, Random Index: 778706
# Counter (Total): 1313, Counter (Yes): 240, Size of already sampled: 1444, Random Index: 624194
# Counter (Total): 1314, Counter (Yes): 240, Size of already sampled: 1445, Random Index: 8757
# Counter (Total): 1315, Counter (Yes): 240, Size of already sampled: 1446, Random Index: 401990
# Counter (Total): 1316, Counter (Yes): 240, Size of already sampled: 1447, Random Index: 790624
# Counter (Total): 1317, Counter (Yes): 241, Size of already sampled: 1448, Random Index: 1028738
# Counter (Total): 1318, Counter (Yes): 242, Size of already sampled: 1449, Random Index: 349910
# Counter (Total): 1319, Counter (Yes): 243, Size of already sampled: 1450, Random Index: 661920
# Counter (Total): 1320, Counter (Yes): 244, Size of already sampled: 1451, Random Index: 694985
# Counter (Total): 1321, Counter (Yes): 245, Size of already sampled: 1452, Random Index: 924323
# Counter (Total): 1322, Counter (Yes): 245, Size of already sampled: 1453, Random Index: 610351
# Counter (Total): 1323, Counter (Yes): 245, Size of already sampled: 1454, Random Index: 569663
# Counter (Total): 1324, Counter (Yes): 245, Size of already sampled: 1455, Random Index: 457581
# Counter (Total): 1325, Counter (Yes): 245, Size of already sampled: 1456, Random Index: 738386
# Counter (Total): 1326, Counter (Yes): 246, Size of already sampled: 1457, Random Index: 663367
# Counter (Total): 1327, Counter (Yes): 246, Size of already sampled: 1458, Random Index: 615438
# Counter (Total): 1328, Counter (Yes): 246, Size of already sampled: 1459, Random Index: 802723
# Counter (Total): 1329, Counter (Yes): 246, Size of already sampled: 1460, Random Index: 233317
# Counter (Total): 1330, Counter (Yes): 246, Size of already sampled: 1461, Random Index: 210787
# Counter (Total): 1331, Counter (Yes): 246, Size of already sampled: 1462, Random Index: 865296
# Counter (Total): 1332, Counter (Yes): 246, Size of already sampled: 1463, Random Index: 958168
# Counter (Total): 1333, Counter (Yes): 246, Size of already sampled: 1464, Random Index: 52036
# Counter (Total): 1334, Counter (Yes): 246, Size of already sampled: 1465, Random Index: 332353
# Counter (Total): 1335, Counter (Yes): 246, Size of already sampled: 1466, Random Index: 608194
# Counter (Total): 1336, Counter (Yes): 246, Size of already sampled: 1467, Random Index: 245547
# Counter (Total): 1337, Counter (Yes): 246, Size of already sampled: 1468, Random Index: 208893
# Counter (Total): 1338, Counter (Yes): 246, Size of already sampled: 1469, Random Index: 1027554
# Counter (Total): 1339, Counter (Yes): 246, Size of already sampled: 1470, Random Index: 765843
# Counter (Total): 1340, Counter (Yes): 246, Size of already sampled: 1471, Random Index: 299369
# Counter (Total): 1341, Counter (Yes): 247, Size of already sampled: 1472, Random Index: 452137
# Counter (Total): 1342, Counter (Yes): 247, Size of already sampled: 1473, Random Index: 434841
# Counter (Total): 1343, Counter (Yes): 247, Size of already sampled: 1474, Random Index: 325245
# Counter (Total): 1344, Counter (Yes): 247, Size of already sampled: 1475, Random Index: 135807
# Counter (Total): 1345, Counter (Yes): 247, Size of already sampled: 1476, Random Index: 677426
# Counter (Total): 1346, Counter (Yes): 247, Size of already sampled: 1477, Random Index: 289251
# Counter (Total): 1347, Counter (Yes): 247, Size of already sampled: 1478, Random Index: 141495
# Counter (Total): 1348, Counter (Yes): 247, Size of already sampled: 1479, Random Index: 708664
# Counter (Total): 1349, Counter (Yes): 247, Size of already sampled: 1480, Random Index: 318113
# Counter (Total): 1350, Counter (Yes): 247, Size of already sampled: 1481, Random Index: 432897
# Counter (Total): 1351, Counter (Yes): 247, Size of already sampled: 1482, Random Index: 146560
# Counter (Total): 1352, Counter (Yes): 247, Size of already sampled: 1483, Random Index: 418878
# Counter (Total): 1353, Counter (Yes): 247, Size of already sampled: 1484, Random Index: 674463
# Counter (Total): 1354, Counter (Yes): 247, Size of already sampled: 1485, Random Index: 985816
# Counter (Total): 1355, Counter (Yes): 248, Size of already sampled: 1486, Random Index: 398393
# Counter (Total): 1356, Counter (Yes): 249, Size of already sampled: 1487, Random Index: 533361
# Counter (Total): 1357, Counter (Yes): 249, Size of already sampled: 1488, Random Index: 337076
# Counter (Total): 1358, Counter (Yes): 250, Size of already sampled: 1489, Random Index: 987424
# Counter (Total): 1359, Counter (Yes): 251, Size of already sampled: 1490, Random Index: 678305
# Counter (Total): 1360, Counter (Yes): 251, Size of already sampled: 1491, Random Index: 270865
# Counter (Total): 1361, Counter (Yes): 251, Size of already sampled: 1492, Random Index: 529347
# Counter (Total): 1362, Counter (Yes): 251, Size of already sampled: 1493, Random Index: 948333
# Counter (Total): 1363, Counter (Yes): 251, Size of already sampled: 1494, Random Index: 963154
# Counter (Total): 1364, Counter (Yes): 251, Size of already sampled: 1495, Random Index: 604033
# Counter (Total): 1365, Counter (Yes): 251, Size of already sampled: 1496, Random Index: 364611
# Counter (Total): 1366, Counter (Yes): 251, Size of already sampled: 1497, Random Index: 465157
# Counter (Total): 1367, Counter (Yes): 251, Size of already sampled: 1498, Random Index: 697920
# Counter (Total): 1368, Counter (Yes): 251, Size of already sampled: 1499, Random Index: 196617
# Counter (Total): 1369, Counter (Yes): 251, Size of already sampled: 1500, Random Index: 832731
# Counter (Total): 1370, Counter (Yes): 251, Size of already sampled: 1501, Random Index: 104696
# Counter (Total): 1371, Counter (Yes): 251, Size of already sampled: 1502, Random Index: 626338
# Counter (Total): 1372, Counter (Yes): 251, Size of already sampled: 1503, Random Index: 516034
# Counter (Total): 1373, Counter (Yes): 251, Size of already sampled: 1504, Random Index: 55423
# Counter (Total): 1374, Counter (Yes): 252, Size of already sampled: 1505, Random Index: 576786
# Counter (Total): 1375, Counter (Yes): 253, Size of already sampled: 1506, Random Index: 796445

# %% [markdown]
# # Resample 1 more row due to inaccurate prediction

# %%
# content_analysis_dataset = read_csv('../master-of-engineering/Assets/BigQuery/content_analysis_dataset.csv')
# experiment_dataset_total_rows = experiment_dataset.shape[0]
# indices_already_sampled = list(experiment_dataset.loc[experiment_dataset['comment_id'].isin(content_analysis_dataset['comment_id'])].index)
# print(indices_already_sampled)

# %%
# from random import choice

# while True:
#     random_index = choice([i for i in range(0, experiment_dataset_total_rows) if i not in indices_already_sampled])
#     indices_already_sampled.append(random_index)
#     row = experiment_dataset.loc[random_index]
#     body = row['body']
#     comment_is_by_author = row['comment_is_by_author']
#     dialogue_act_classification = dac_factory.classify(body)
#     prediction = pcc_clf.predict(
#         DataFrame(
#             {
#                 'body': [body], 
#                 'comment_is_by_author': [comment_is_by_author], 
#                 'dialogue_act_classification_ml': [dialogue_act_classification]
#             }))

#     if prediction[0] == 'Yes':
#         row['dialogue_act_classification_ml'] = dialogue_act_classification
#         row['topic_keywords'] = ''
#         row['program_comprehension_challenge'] = prediction[0]
#         row['problem_encountered'] = ''
#         content_analysis_dataset = content_analysis_dataset.append(row)
#         break

#     print(f'Size of already sampled: {len(indices_already_sampled)}, Random Index: {random_index}')

# content_analysis_dataset.to_csv('../master-of-engineering/Assets/BigQuery/content_analysis_dataset.csv', index=False, header=True, mode='w')
