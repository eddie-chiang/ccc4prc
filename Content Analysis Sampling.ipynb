# %%
from classifier import DialogueActClassifierFactory
from joblib import load
from pandas import DataFrame, option_context, read_csv
from pathlib import Path

clf_grid_search_cv = load('./models/program_comprehension_challenge_gridsearchcv.pickle') 
clf_pipeline_decision_tree = load('./models/program_comprehension_challenge_classifier.pickle') 
dac_factory = DialogueActClassifierFactory()
dac_clf = dac_factory.get_classifier(classifier_file=Path('./models/dialogue_act_classifier.pickle'), test_set_percentage=10)

training_dataset = read_csv('../master-of-engineering/Assets/BigQuery/training_dataset.csv')
test_dataset = read_csv('../master-of-engineering/Assets/BigQuery/test_dataset.csv')

FEATURES = ['body', 'dialogue_act_classification_ml', 'comment_is_by_author']
LABEL = 'program_comprehension_challenge'

X_train = training_dataset[FEATURES]
X_test = test_dataset[FEATURES]
y_train = training_dataset[LABEL]
y_true = test_dataset[LABEL]

# %%
from sklearn import metrics

clf_pipeline_decision_tree.fit(X_train, y_train)
y_pred = clf_pipeline_decision_tree.predict(X_test)

report = metrics.classification_report(y_true, y_pred, digits=8)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#           No  0.92857143 0.81981982 0.87081340       111
#          Yes  0.61538462 0.82051282 0.70329670        39
#
#     accuracy                      0.82000000       150
#    macro avg  0.77197802 0.82016632 0.78705505       150
# weighted avg  0.84714286 0.82000000 0.82725906       150

# %%
experiment_dataset = read_csv('/Volumes/RamDisk/results_20190503_1403_cleaned.csv')

# %%
from pandas import concat

content_analysis_dataset = concat([
    training_dataset.loc[training_dataset['program_comprehension_challenge']=='Yes'], 
    test_dataset.loc[test_dataset['program_comprehension_challenge']=='Yes']
    ])

content_analysis_dataset.to_csv('../master-of-engineering/Assets/BigQuery/content_analysis_dataset.csv', index=False, header=True, mode='w')

sample_size = 384 - content_analysis_dataset.shape[0] # 95% Confidence Level + 5% Confidence Interval with a population of 1036743 -> Sample Size = 384, already analyzed in training dataset and test dataset.

# %%
experiment_dataset_total_rows = experiment_dataset.shape[0]
print(experiment_dataset_total_rows)
indices_already_sampled = list(experiment_dataset.loc[experiment_dataset['comment_id'].isin(content_analysis_dataset['comment_id'])].index)
print(indices_already_sampled)
# Out:
# 1036743
# [509, 726, 17798, 24155, 32099, 36464, 43032, 54431, 56313, 69258, 73270, 80162, 90511, 105051, 110503, 129628, 132855, 133232, 133516, 163355, 167086, 185939, 189728, 197447, 209669, 214812, 232697, 235018, 246296, 252758, 258339, 259928, 270277, 274453, 284698, 297264, 315545, 330692, 333599, 338031, 340343, 346345, 354605, 364763, 368760, 373140, 380565, 380639, 389432, 403936, 405359, 413884, 424418, 432183, 436822, 456947, 461248, 474321, 506840, 513293, 522487, 526100, 527975, 534546, 536108, 542999, 547634, 565844, 566844, 579035, 595607, 596015, 600716, 609584, 611753, 615305, 619572, 622248, 626921, 632953, 644196, 664099, 668030, 668995, 690642, 701256, 705033, 707035, 715644, 726526, 733106, 752516, 761659, 762103, 762279, 765988, 775082, 776089, 805526, 810905, 813272, 814306, 818502, 818629, 824256, 827388, 836138, 841892, 843924, 857463, 866385, 868061, 886945, 887040, 907182, 916756, 919472, 935851, 947274, 947500, 951413, 956529, 976020, 987354, 990899, 991399, 999428, 1003989, 1005538, 1032415, 1035319]

# %%
from random import choice

experiment_dataset_range = range(0, experiment_dataset_total_rows)
counter_yes = 0
counter_total = 0
while counter_yes < sample_size:
    counter_total += 1
    random_index = choice([i for i in experiment_dataset_range if i not in indices_already_sampled])
    indices_already_sampled.append(random_index)
    row = experiment_dataset.loc[random_index]
    body = row['body']
    comment_is_by_author = row['comment_is_by_author']
    dialogue_act_classification = dac_factory.classify(body)
    prediction = clf_pipeline_decision_tree.predict(
        DataFrame(
            {
                'body': [body], 
                'comment_is_by_author': [comment_is_by_author], 
                'dialogue_act_classification_ml': [dialogue_act_classification]
            }))

    if prediction[0] == 'Yes':
        row['dialogue_act_classification_ml'] = dialogue_act_classification
        row['topic_keywords'] = ''
        row['program_comprehension_challenge'] = prediction[0]
        row['problem_encountered'] = ''
        content_analysis_dataset = content_analysis_dataset.append(row)
        counter_yes += 1  

    print(f'Counter (Total): {counter_total}, Counter (Yes): {counter_yes}, Size of already sampled: {len(indices_already_sampled)}, Random Index: {random_index}')

content_analysis_dataset.to_csv('../master-of-engineering/Assets/BigQuery/content_analysis_dataset.csv', index=False, header=True, mode='w')
# Out:
# ): 686, Counter (Yes): 190, Size of already sampled: 817, Random Index: 388023
# Counter (Total): 687, Counter (Yes): 190, Size of already sampled: 818, Random Index: 936853
# Counter (Total): 688, Counter (Yes): 191, Size of already sampled: 819, Random Index: 645060
# Counter (Total): 689, Counter (Yes): 191, Size of already sampled: 820, Random Index: 9722
# Counter (Total): 690, Counter (Yes): 191, Size of already sampled: 821, Random Index: 839795
# Counter (Total): 691, Counter (Yes): 192, Size of already sampled: 822, Random Index: 547019
# Counter (Total): 692, Counter (Yes): 192, Size of already sampled: 823, Random Index: 905737
# Counter (Total): 693, Counter (Yes): 192, Size of already sampled: 824, Random Index: 147694
# Counter (Total): 694, Counter (Yes): 193, Size of already sampled: 825, Random Index: 540420
# Counter (Total): 695, Counter (Yes): 194, Size of already sampled: 826, Random Index: 16136
# Counter (Total): 696, Counter (Yes): 194, Size of already sampled: 827, Random Index: 740877
# Counter (Total): 697, Counter (Yes): 194, Size of already sampled: 828, Random Index: 310823
# Counter (Total): 698, Counter (Yes): 195, Size of already sampled: 829, Random Index: 787824
# Counter (Total): 699, Counter (Yes): 195, Size of already sampled: 830, Random Index: 521674
# Counter (Total): 700, Counter (Yes): 196, Size of already sampled: 831, Random Index: 527670
# Counter (Total): 701, Counter (Yes): 196, Size of already sampled: 832, Random Index: 358308
# Counter (Total): 702, Counter (Yes): 197, Size of already sampled: 833, Random Index: 818165
# Counter (Total): 703, Counter (Yes): 198, Size of already sampled: 834, Random Index: 68549
# Counter (Total): 704, Counter (Yes): 198, Size of already sampled: 835, Random Index: 227785
# Counter (Total): 705, Counter (Yes): 199, Size of already sampled: 836, Random Index: 139913
# Counter (Total): 706, Counter (Yes): 199, Size of already sampled: 837, Random Index: 785728
# Counter (Total): 707, Counter (Yes): 199, Size of already sampled: 838, Random Index: 969082
# Counter (Total): 708, Counter (Yes): 200, Size of already sampled: 839, Random Index: 901286
# Counter (Total): 709, Counter (Yes): 200, Size of already sampled: 840, Random Index: 738854
# Counter (Total): 710, Counter (Yes): 201, Size of already sampled: 841, Random Index: 163821
# Counter (Total): 711, Counter (Yes): 201, Size of already sampled: 842, Random Index: 240545
# Counter (Total): 712, Counter (Yes): 201, Size of already sampled: 843, Random Index: 576929
# Counter (Total): 713, Counter (Yes): 201, Size of already sampled: 844, Random Index: 972609
# Counter (Total): 714, Counter (Yes): 201, Size of already sampled: 845, Random Index: 653235
# Counter (Total): 715, Counter (Yes): 201, Size of already sampled: 846, Random Index: 1009286
# Counter (Total): 716, Counter (Yes): 201, Size of already sampled: 847, Random Index: 187452
# Counter (Total): 717, Counter (Yes): 201, Size of already sampled: 848, Random Index: 103830
# Counter (Total): 718, Counter (Yes): 201, Size of already sampled: 849, Random Index: 179398
# Counter (Total): 719, Counter (Yes): 201, Size of already sampled: 850, Random Index: 127287
# Counter (Total): 720, Counter (Yes): 201, Size of already sampled: 851, Random Index: 259744
# Counter (Total): 721, Counter (Yes): 201, Size of already sampled: 852, Random Index: 632479
# Counter (Total): 722, Counter (Yes): 201, Size of already sampled: 853, Random Index: 521660
# Counter (Total): 723, Counter (Yes): 201, Size of already sampled: 854, Random Index: 706367
# Counter (Total): 724, Counter (Yes): 201, Size of already sampled: 855, Random Index: 844876
# Counter (Total): 725, Counter (Yes): 201, Size of already sampled: 856, Random Index: 607088
# Counter (Total): 726, Counter (Yes): 201, Size of already sampled: 857, Random Index: 392333
# Counter (Total): 727, Counter (Yes): 201, Size of already sampled: 858, Random Index: 774102
# Counter (Total): 728, Counter (Yes): 201, Size of already sampled: 859, Random Index: 195778
# Counter (Total): 729, Counter (Yes): 202, Size of already sampled: 860, Random Index: 838327
# Counter (Total): 730, Counter (Yes): 203, Size of already sampled: 861, Random Index: 461119
# Counter (Total): 731, Counter (Yes): 203, Size of already sampled: 862, Random Index: 462380
# Counter (Total): 732, Counter (Yes): 203, Size of already sampled: 863, Random Index: 689433
# Counter (Total): 733, Counter (Yes): 203, Size of already sampled: 864, Random Index: 153628
# Counter (Total): 734, Counter (Yes): 203, Size of already sampled: 865, Random Index: 751823
# Counter (Total): 735, Counter (Yes): 203, Size of already sampled: 866, Random Index: 575807
# Counter (Total): 736, Counter (Yes): 204, Size of already sampled: 867, Random Index: 106425
# Counter (Total): 737, Counter (Yes): 205, Size of already sampled: 868, Random Index: 73625
# Counter (Total): 738, Counter (Yes): 205, Size of already sampled: 869, Random Index: 160501
# Counter (Total): 739, Counter (Yes): 205, Size of already sampled: 870, Random Index: 157005
# Counter (Total): 740, Counter (Yes): 205, Size of already sampled: 871, Random Index: 438975
# Counter (Total): 741, Counter (Yes): 205, Size of already sampled: 872, Random Index: 580517
# Counter (Total): 742, Counter (Yes): 205, Size of already sampled: 873, Random Index: 637990
# Counter (Total): 743, Counter (Yes): 206, Size of already sampled: 874, Random Index: 187565
# Counter (Total): 744, Counter (Yes): 207, Size of already sampled: 875, Random Index: 998887
# Counter (Total): 745, Counter (Yes): 207, Size of already sampled: 876, Random Index: 475674
# Counter (Total): 746, Counter (Yes): 208, Size of already sampled: 877, Random Index: 1018756
# Counter (Total): 747, Counter (Yes): 208, Size of already sampled: 878, Random Index: 312797
# Counter (Total): 748, Counter (Yes): 208, Size of already sampled: 879, Random Index: 176919
# Counter (Total): 749, Counter (Yes): 209, Size of already sampled: 880, Random Index: 1021605
# Counter (Total): 750, Counter (Yes): 209, Size of already sampled: 881, Random Index: 485366
# Counter (Total): 751, Counter (Yes): 210, Size of already sampled: 882, Random Index: 909797
# Counter (Total): 752, Counter (Yes): 210, Size of already sampled: 883, Random Index: 843231
# Counter (Total): 753, Counter (Yes): 210, Size of already sampled: 884, Random Index: 946172
# Counter (Total): 754, Counter (Yes): 211, Size of already sampled: 885, Random Index: 1004273
# Counter (Total): 755, Counter (Yes): 211, Size of already sampled: 886, Random Index: 185210
# Counter (Total): 756, Counter (Yes): 211, Size of already sampled: 887, Random Index: 716408
# Counter (Total): 757, Counter (Yes): 211, Size of already sampled: 888, Random Index: 93264
# Counter (Total): 758, Counter (Yes): 211, Size of already sampled: 889, Random Index: 90285
# Counter (Total): 759, Counter (Yes): 211, Size of already sampled: 890, Random Index: 376630
# Counter (Total): 760, Counter (Yes): 211, Size of already sampled: 891, Random Index: 746313
# Counter (Total): 761, Counter (Yes): 212, Size of already sampled: 892, Random Index: 124241
# Counter (Total): 762, Counter (Yes): 212, Size of already sampled: 893, Random Index: 248788
# Counter (Total): 763, Counter (Yes): 212, Size of already sampled: 894, Random Index: 352139
# Counter (Total): 764, Counter (Yes): 213, Size of already sampled: 895, Random Index: 591706
# Counter (Total): 765, Counter (Yes): 214, Size of already sampled: 896, Random Index: 1009204
# Counter (Total): 766, Counter (Yes): 215, Size of already sampled: 897, Random Index: 223203
# Counter (Total): 767, Counter (Yes): 215, Size of already sampled: 898, Random Index: 114259
# Counter (Total): 768, Counter (Yes): 215, Size of already sampled: 899, Random Index: 296959
# Counter (Total): 769, Counter (Yes): 215, Size of already sampled: 900, Random Index: 854324
# Counter (Total): 770, Counter (Yes): 215, Size of already sampled: 901, Random Index: 328122
# Counter (Total): 771, Counter (Yes): 215, Size of already sampled: 902, Random Index: 709018
# Counter (Total): 772, Counter (Yes): 216, Size of already sampled: 903, Random Index: 528072
# Counter (Total): 773, Counter (Yes): 216, Size of already sampled: 904, Random Index: 525704
# Counter (Total): 774, Counter (Yes): 216, Size of already sampled: 905, Random Index: 145552
# Counter (Total): 775, Counter (Yes): 217, Size of already sampled: 906, Random Index: 998039
# Counter (Total): 776, Counter (Yes): 217, Size of already sampled: 907, Random Index: 557728
# Counter (Total): 777, Counter (Yes): 217, Size of already sampled: 908, Random Index: 811713
# Counter (Total): 778, Counter (Yes): 217, Size of already sampled: 909, Random Index: 638901
# Counter (Total): 779, Counter (Yes): 218, Size of already sampled: 910, Random Index: 272302
# Counter (Total): 780, Counter (Yes): 219, Size of already sampled: 911, Random Index: 199034
# Counter (Total): 781, Counter (Yes): 220, Size of already sampled: 912, Random Index: 884403
# Counter (Total): 782, Counter (Yes): 220, Size of already sampled: 913, Random Index: 481039
# Counter (Total): 783, Counter (Yes): 220, Size of already sampled: 914, Random Index: 999460
# Counter (Total): 784, Counter (Yes): 220, Size of already sampled: 915, Random Index: 844829
# Counter (Total): 785, Counter (Yes): 220, Size of already sampled: 916, Random Index: 530599
# Counter (Total): 786, Counter (Yes): 220, Size of already sampled: 917, Random Index: 403708
# Counter (Total): 787, Counter (Yes): 220, Size of already sampled: 918, Random Index: 729147
# Counter (Total): 788, Counter (Yes): 221, Size of already sampled: 919, Random Index: 13246
# Counter (Total): 789, Counter (Yes): 222, Size of already sampled: 920, Random Index: 439218
# Counter (Total): 790, Counter (Yes): 223, Size of already sampled: 921, Random Index: 504911
# Counter (Total): 791, Counter (Yes): 223, Size of already sampled: 922, Random Index: 1015128
# Counter (Total): 792, Counter (Yes): 223, Size of already sampled: 923, Random Index: 8557
# Counter (Total): 793, Counter (Yes): 223, Size of already sampled: 924, Random Index: 603687
# Counter (Total): 794, Counter (Yes): 223, Size of already sampled: 925, Random Index: 889775
# Counter (Total): 795, Counter (Yes): 223, Size of already sampled: 926, Random Index: 81032
# Counter (Total): 796, Counter (Yes): 224, Size of already sampled: 927, Random Index: 87230
# Counter (Total): 797, Counter (Yes): 224, Size of already sampled: 928, Random Index: 781613
# Counter (Total): 798, Counter (Yes): 224, Size of already sampled: 929, Random Index: 457959
# Counter (Total): 799, Counter (Yes): 225, Size of already sampled: 930, Random Index: 652808
# Counter (Total): 800, Counter (Yes): 225, Size of already sampled: 931, Random Index: 203094
# Counter (Total): 801, Counter (Yes): 225, Size of already sampled: 932, Random Index: 976065
# Counter (Total): 802, Counter (Yes): 225, Size of already sampled: 933, Random Index: 292458
# Counter (Total): 803, Counter (Yes): 225, Size of already sampled: 934, Random Index: 836790
# Counter (Total): 804, Counter (Yes): 225, Size of already sampled: 935, Random Index: 284081
# Counter (Total): 805, Counter (Yes): 226, Size of already sampled: 936, Random Index: 149293
# Counter (Total): 806, Counter (Yes): 227, Size of already sampled: 937, Random Index: 343384
# Counter (Total): 807, Counter (Yes): 227, Size of already sampled: 938, Random Index: 884425
# Counter (Total): 808, Counter (Yes): 227, Size of already sampled: 939, Random Index: 668672
# Counter (Total): 809, Counter (Yes): 227, Size of already sampled: 940, Random Index: 599018
# Counter (Total): 810, Counter (Yes): 227, Size of already sampled: 941, Random Index: 844661
# Counter (Total): 811, Counter (Yes): 227, Size of already sampled: 942, Random Index: 782927
# Counter (Total): 812, Counter (Yes): 227, Size of already sampled: 943, Random Index: 644063
# Counter (Total): 813, Counter (Yes): 227, Size of already sampled: 944, Random Index: 527900
# Counter (Total): 814, Counter (Yes): 227, Size of already sampled: 945, Random Index: 715662
# Counter (Total): 815, Counter (Yes): 227, Size of already sampled: 946, Random Index: 13185
# Counter (Total): 816, Counter (Yes): 227, Size of already sampled: 947, Random Index: 283969
# Counter (Total): 817, Counter (Yes): 227, Size of already sampled: 948, Random Index: 507586
# Counter (Total): 818, Counter (Yes): 228, Size of already sampled: 949, Random Index: 860397
# Counter (Total): 819, Counter (Yes): 228, Size of already sampled: 950, Random Index: 139952
# Counter (Total): 820, Counter (Yes): 228, Size of already sampled: 951, Random Index: 916523
# Counter (Total): 821, Counter (Yes): 229, Size of already sampled: 952, Random Index: 25351
# Counter (Total): 822, Counter (Yes): 229, Size of already sampled: 953, Random Index: 355064
# Counter (Total): 823, Counter (Yes): 229, Size of already sampled: 954, Random Index: 731418
# Counter (Total): 824, Counter (Yes): 229, Size of already sampled: 955, Random Index: 493977
# Counter (Total): 825, Counter (Yes): 229, Size of already sampled: 956, Random Index: 272449
# Counter (Total): 826, Counter (Yes): 229, Size of already sampled: 957, Random Index: 412622
# Counter (Total): 827, Counter (Yes): 229, Size of already sampled: 958, Random Index: 757762
# Counter (Total): 828, Counter (Yes): 230, Size of already sampled: 959, Random Index: 380355
# Counter (Total): 829, Counter (Yes): 230, Size of already sampled: 960, Random Index: 336815
# Counter (Total): 830, Counter (Yes): 230, Size of already sampled: 961, Random Index: 495112
# Counter (Total): 831, Counter (Yes): 230, Size of already sampled: 962, Random Index: 653159
# Counter (Total): 832, Counter (Yes): 230, Size of already sampled: 963, Random Index: 644983
# Counter (Total): 833, Counter (Yes): 230, Size of already sampled: 964, Random Index: 999972
# Counter (Total): 834, Counter (Yes): 230, Size of already sampled: 965, Random Index: 496426
# Counter (Total): 835, Counter (Yes): 230, Size of already sampled: 966, Random Index: 923741
# Counter (Total): 836, Counter (Yes): 231, Size of already sampled: 967, Random Index: 314753
# Counter (Total): 837, Counter (Yes): 231, Size of already sampled: 968, Random Index: 975220
# Counter (Total): 838, Counter (Yes): 231, Size of already sampled: 969, Random Index: 975097
# Counter (Total): 839, Counter (Yes): 232, Size of already sampled: 970, Random Index: 531067
# Counter (Total): 840, Counter (Yes): 232, Size of already sampled: 971, Random Index: 939502
# Counter (Total): 841, Counter (Yes): 232, Size of already sampled: 972, Random Index: 345843
# Counter (Total): 842, Counter (Yes): 233, Size of already sampled: 973, Random Index: 746380
# Counter (Total): 843, Counter (Yes): 233, Size of already sampled: 974, Random Index: 294868
# Counter (Total): 844, Counter (Yes): 234, Size of already sampled: 975, Random Index: 817469
# Counter (Total): 845, Counter (Yes): 234, Size of already sampled: 976, Random Index: 202106
# Counter (Total): 846, Counter (Yes): 234, Size of already sampled: 977, Random Index: 370462
# Counter (Total): 847, Counter (Yes): 235, Size of already sampled: 978, Random Index: 688213
# Counter (Total): 848, Counter (Yes): 235, Size of already sampled: 979, Random Index: 632487
# Counter (Total): 849, Counter (Yes): 235, Size of already sampled: 980, Random Index: 64029
# Counter (Total): 850, Counter (Yes): 235, Size of already sampled: 981, Random Index: 953908
# Counter (Total): 851, Counter (Yes): 235, Size of already sampled: 982, Random Index: 738783
# Counter (Total): 852, Counter (Yes): 235, Size of already sampled: 983, Random Index: 392297
# Counter (Total): 853, Counter (Yes): 236, Size of already sampled: 984, Random Index: 960492
# Counter (Total): 854, Counter (Yes): 236, Size of already sampled: 985, Random Index: 901840
# Counter (Total): 855, Counter (Yes): 236, Size of already sampled: 986, Random Index: 888713
# Counter (Total): 856, Counter (Yes): 236, Size of already sampled: 987, Random Index: 868546
# Counter (Total): 857, Counter (Yes): 236, Size of already sampled: 988, Random Index: 905034
# Counter (Total): 858, Counter (Yes): 237, Size of already sampled: 989, Random Index: 552180
# Counter (Total): 859, Counter (Yes): 238, Size of already sampled: 990, Random Index: 565124
# Counter (Total): 860, Counter (Yes): 238, Size of already sampled: 991, Random Index: 341519
# Counter (Total): 861, Counter (Yes): 238, Size of already sampled: 992, Random Index: 965762
# Counter (Total): 862, Counter (Yes): 238, Size of already sampled: 993, Random Index: 242493
# Counter (Total): 863, Counter (Yes): 238, Size of already sampled: 994, Random Index: 891291
# Counter (Total): 864, Counter (Yes): 238, Size of already sampled: 995, Random Index: 880070
# Counter (Total): 865, Counter (Yes): 238, Size of already sampled: 996, Random Index: 406647
# Counter (Total): 866, Counter (Yes): 238, Size of already sampled: 997, Random Index: 64038
# Counter (Total): 867, Counter (Yes): 239, Size of already sampled: 998, Random Index: 523089
# Counter (Total): 868, Counter (Yes): 240, Size of already sampled: 999, Random Index: 147488
# Counter (Total): 869, Counter (Yes): 241, Size of already sampled: 1000, Random Index: 633275
# Counter (Total): 870, Counter (Yes): 241, Size of already sampled: 1001, Random Index: 489383
# Counter (Total): 871, Counter (Yes): 241, Size of already sampled: 1002, Random Index: 987891
# Counter (Total): 872, Counter (Yes): 242, Size of already sampled: 1003, Random Index: 287773
# Counter (Total): 873, Counter (Yes): 242, Size of already sampled: 1004, Random Index: 1027121
# Counter (Total): 874, Counter (Yes): 243, Size of already sampled: 1005, Random Index: 974134
# Counter (Total): 875, Counter (Yes): 243, Size of already sampled: 1006, Random Index: 283186
# Counter (Total): 876, Counter (Yes): 244, Size of already sampled: 1007, Random Index: 81865
# Counter (Total): 877, Counter (Yes): 245, Size of already sampled: 1008, Random Index: 133322
# Counter (Total): 878, Counter (Yes): 245, Size of already sampled: 1009, Random Index: 469301
# Counter (Total): 879, Counter (Yes): 245, Size of already sampled: 1010, Random Index: 880636
# Counter (Total): 880, Counter (Yes): 246, Size of already sampled: 1011, Random Index: 382827
# Counter (Total): 881, Counter (Yes): 247, Size of already sampled: 1012, Random Index: 652996
# Counter (Total): 882, Counter (Yes): 248, Size of already sampled: 1013, Random Index: 700803
# Counter (Total): 883, Counter (Yes): 249, Size of already sampled: 1014, Random Index: 707868
# Counter (Total): 884, Counter (Yes): 249, Size of already sampled: 1015, Random Index: 40097
# Counter (Total): 885, Counter (Yes): 249, Size of already sampled: 1016, Random Index: 707810
# Counter (Total): 886, Counter (Yes): 249, Size of already sampled: 1017, Random Index: 756442
# Counter (Total): 887, Counter (Yes): 249, Size of already sampled: 1018, Random Index: 615676
# Counter (Total): 888, Counter (Yes): 249, Size of already sampled: 1019, Random Index: 25282
# Counter (Total): 889, Counter (Yes): 250, Size of already sampled: 1020, Random Index: 15721
# Counter (Total): 890, Counter (Yes): 250, Size of already sampled: 1021, Random Index: 892452
# Counter (Total): 891, Counter (Yes): 251, Size of already sampled: 1022, Random Index: 523443
# Counter (Total): 892, Counter (Yes): 251, Size of already sampled: 1023, Random Index: 498761
# Counter (Total): 893, Counter (Yes): 251, Size of already sampled: 1024, Random Index: 827789
# Counter (Total): 894, Counter (Yes): 251, Size of already sampled: 1025, Random Index: 295464
# Counter (Total): 895, Counter (Yes): 251, Size of already sampled: 1026, Random Index: 431574
# Counter (Total): 896, Counter (Yes): 251, Size of already sampled: 1027, Random Index: 549818
# Counter (Total): 897, Counter (Yes): 251, Size of already sampled: 1028, Random Index: 761899
# Counter (Total): 898, Counter (Yes): 252, Size of already sampled: 1029, Random Index: 567061
# Counter (Total): 899, Counter (Yes): 252, Size of already sampled: 1030, Random Index: 749038
# Counter (Total): 900, Counter (Yes): 253, Size of already sampled: 1031, Random Index: 998975

# %% [markdown]
# # Resample 1 more row due to inaccurate prediction

# %%
content_analysis_dataset = read_csv('../master-of-engineering/Assets/BigQuery/content_analysis_dataset.csv')
experiment_dataset_total_rows = experiment_dataset.shape[0]
indices_already_sampled = list(experiment_dataset.loc[experiment_dataset['comment_id'].isin(content_analysis_dataset['comment_id'])].index)
print(indices_already_sampled)
# Out:
# [509, 726, 5214, 13246, 15721, 16136, 17798, 18033, 18485, 23560, 24155, 25351, 27372, 31189, 31224, 32099, 36464, 37069, 43032, 46187, 48764, 50359, 54431, 56313, 64978, 68549, 69258, 73270, 73625, 80162, 81554, 81865, 83585, 83869, 87230, 87962, 90511, 92806, 105051, 106425, 110503, 111094, 112501, 120123, 122380, 123414, 124241, 129628, 132855, 133232, 133322, 133516, 139354, 139913, 147488, 148545, 149293, 159932, 163355, 163821, 167086, 167857, 168095, 170801, 171532, 176238, 178384, 178896, 183477, 185939, 187565, 189728, 191399, 192144, 192233, 194173, 194404, 197447, 199034, 201840, 203370, 209669, 214552, 214812, 220419, 221723, 223203, 232697, 235018, 245152, 246296, 251501, 252758, 252787, 258339, 259928, 263737, 270277, 272302, 274453, 279697, 281703, 284698, 287628, 287773, 289801, 297264, 298107, 314753, 315545, 315794, 330692, 333599, 336061, 338031, 338199, 340343, 343384, 345160, 345881, 346345, 346918, 351878, 354162, 354605, 360921, 364763, 368760, 372518, 372560, 373140, 373194, 379212, 379517, 380355, 380565, 380639, 382827, 388023, 389432, 403936, 405359, 407803, 413884, 420727, 423353, 424418, 425571, 426501, 430236, 432183, 436822, 439218, 440435, 449623, 450315, 456947, 459892, 461119, 461248, 464655, 464977, 474222, 474321, 474732, 477080, 479910, 481557, 483394, 501128, 504911, 506840, 511116, 511384, 513293, 519312, 522487, 523089, 523315, 523443, 523521, 526100, 527362, 527670, 527975, 528072, 531067, 534546, 535025, 536108, 540420, 542999, 544126, 547019, 547111, 547634, 552180, 558596, 565124, 565844, 566844, 567061, 579035, 580264, 581764, 582787, 586057, 589924, 591706, 595607, 596015, 596854, 597872, 600538, 600716, 602444, 607801, 609584, 611753, 612754, 615305, 619484, 619572, 622248, 623631, 626921, 632953, 633275, 633596, 635019, 638843, 644196, 645060, 645580, 646760, 652808, 652996, 660519, 663754, 664099, 664236, 667578, 668030, 668995, 671518, 672130, 672601, 681894, 683255, 687008, 688213, 689858, 690642, 692089, 694914, 695001, 700803, 701256, 704616, 705033, 707035, 707868, 715644, 719370, 726526, 727004, 731176, 732046, 733106, 733612, 733910, 745644, 746380, 750620, 752516, 761659, 762103, 762279, 765988, 770031, 770853, 773943, 774333, 775082, 775159, 775327, 776089, 787824, 804703, 805526, 806073, 807823, 810212, 810894, 810905, 813272, 814293, 814306, 817158, 817469, 817828, 818165, 818502, 818629, 819307, 820727, 824256, 824313, 826766, 827388, 834106, 836138, 838327, 841892, 843538, 843924, 852212, 853865, 857463, 860397, 861777, 863543, 864529, 866385, 868061, 878739, 884403, 886945, 887040, 891156, 893582, 900827, 901286, 901417, 902372, 907182, 909797, 913329, 914164, 916756, 919472, 920322, 923326, 924427, 928165, 935851, 935853, 936630, 936926, 943953, 945524, 947274, 947500, 951413, 953317, 956529, 957382, 960492, 965032, 974134, 976020, 980273, 987354, 990676, 990899, 991399, 992033, 998039, 998887, 998975, 999428, 1003625, 1003989, 1004273, 1005538, 1009204, 1017110, 1017730, 1018535, 1018756, 1021605, 1032415, 1034812, 1035319]

# %%
from random import choice

while True:
    random_index = choice([i for i in range(0, experiment_dataset_total_rows) if i not in indices_already_sampled])
    indices_already_sampled.append(random_index)
    row = experiment_dataset.loc[random_index]
    body = row['body']
    comment_is_by_author = row['comment_is_by_author']
    dialogue_act_classification = dac_factory.classify(body)
    prediction = clf_pipeline_decision_tree.predict(
        DataFrame(
            {
                'body': [body], 
                'comment_is_by_author': [comment_is_by_author], 
                'dialogue_act_classification_ml': [dialogue_act_classification]
            }))

    if prediction[0] == 'Yes':
        row['dialogue_act_classification_ml'] = dialogue_act_classification
        row['topic_keywords'] = ''
        row['program_comprehension_challenge'] = prediction[0]
        row['problem_encountered'] = ''
        content_analysis_dataset = content_analysis_dataset.append(row)
        break

    print(f'Size of already sampled: {len(indices_already_sampled)}, Random Index: {random_index}')

content_analysis_dataset.to_csv('../master-of-engineering/Assets/BigQuery/content_analysis_dataset.csv', index=False, header=True, mode='w')
# Out:
# Size of already sampled: 385, Random Index: 73260
# Size of already sampled: 386, Random Index: 679283
# Size of already sampled: 387, Random Index: 137546
# Size of already sampled: 388, Random Index: 491776
